# %%
import tweepy
consumer_key = "consumer_key"
consumer_secret = "consumer_secret"
access_token = "access_token"
access_token_secret = "access_token_secret"
# Create the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Set the access token and secret
auth.set_access_token(access_token, access_token_secret)
# Create the API object while passing in auth information
api = tweepy.API(auth)

# %%
# To test if the API object is working properly, use it to fetch tweets from your timeline

timeline_tweets = api.home_timeline()
# print the text for each tweet

max_tweets = 100
searched_tweets = [status for status in tweepy.Cursor(api.search, q=query).items(max_tweets)]
print searched_tweets
# Out:
# Node News Friday, March 23 Node api, Newly created user, Single page apps &amp; more… https://t.co/VVsl1SKbj7 https://t.co/Dux8aDBrEd
# Vue News Friday, March 23 Nuxt.js, Universal applications, App &amp; more… https://t.co/l2nt9Vg76s https://t.co/fvcXQV6dJ9
# React News Friday, March 23 List page, React native, Var fakerator &amp; more… https://t.co/vTwzFxFpJi https://t.co/mShY9BWxWs
# Angular News Friday, March 23 Bucket list, Bucket list application, Directive &amp; more… https://t.co/xSXUaQSYrx https://t.co/9kCLWXbK0P
# Angular News Friday, March 23 Bucket list, Bucket list application, Directive &amp; more… https://t.co/C75cxN4bFZ https://t.co/fVwX80PttM
# Ionic's very own Harvey is hard at work building PWAs on ionic on #nationalpuppyday #PWA https://t.co/Wb4utiSOHF https://t.co/Y1DP5KWPds
# RT @ericsimons40: Alright we're making it official. Starting today, @iamalbertpai and I are officially working full time on @stackblitz 🎉…
# ...

# %%
# query term to fetch the data
query = "MarchMadness"
results = api.search(q=query, lang=language, count=10000)
for tweet in results:
   print tweet.user.screen_name,"Tweeted:",tweet.text
# Out:
# teddyD66 Tweeted: RT @marchmadness: Can't watch the game? LISTEN to the game with #WestwoodOne!
#
# English pregame begins at 3:30pm ET, and Spanish at 6pm ET.…
# beany1436 Tweeted: RT @PanicAtTheDisco: One more day, San Antonio 👋 see you tomorrow at @CapitalOne #JamFest https://t.co/mlepurEFHW https://t.co/3hGImGEq32
# Michelleka0010 Tweeted: RT @PanicAtTheDisco: One more day, San Antonio 👋 see you tomorrow at @CapitalOne #JamFest https://t.co/mlepurEFHW https://t.co/3hGImGEq32
# J9Gaming Tweeted: RT @PanicAtTheDisco: One more day, San Antonio 👋 see you tomorrow at @CapitalOne #JamFest https://t.co/mlepurEFHW https://t.co/3hGImGEq32
# DatBoiFromCLE Tweeted: RT @desnich_42: Everyone thinks they're a baller during #marchmadness 😂 @KingJames #Silencer https://t.co/gSTDCANOP7
# Hypebeast_13 Tweeted: I'm picking the Kansas Jayhawks to beat Villanova in the #FinalFour. Who you got? #MarchMadness @RocketMortgage https://t.co/TUxuBA3Igl
# ...

# %%
#Save the tweets in a file
api = tweepy.API(auth)
query = "#MarchMadness"
max_tweets = 100
searched_tweets = [status for status in tweepy.Cursor(api.search, q=query).items(max_tweets)]
print searched_tweets
# Out:
# [Status(contributors=None, truncated=False, text=u"I'm picking the Kansas Jayhawks to beat Villanova in the #FinalFour. Who you got? #MarchMadness @RocketMortgage\nhttps://t.co/cJG0lL6eXk", is_quote_status=False, in_reply_to_status_id=None, id=980150717603295233, favorite_count=0, _api=<tweepy.api.API object at 0x7f347c1b01d0>, author=User(follow_request_sent=False, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 2166608137, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/853016405834379264/-wSowUZ4_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 154, u'profil
# ...
